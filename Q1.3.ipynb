# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
import numpy as np                             # import numpy library as np
import matplotlib.pyplot as plt                # import mathpltlib.pyplot library as plt

n = np.linspace(0,100,101)                     # creating a space of from 0 to 100 i.e. 101 with 101 samples i.e. 1 unit b/w each point
y = np.zeros(101)                              # output array

#generate unit step signal 
u = np.ones(101)                               # unit step signal

x = np.zeros(101)                              # define the array of x initially    
y[-1]=1                                        # initial condition
a=0.9                                          # alpha assumed as 0.9
for i in range(len(n)):                        # till the range of we hv to get the x                                  
    x[i] = a**i*u[i]                           # define the x at every i value till n
    print(x[i])                                # print to cross verify 
plt.plot(n,x)                                  # plot the x vs n graph
plt.xlabel("n")
plt.ylabel("S[n]")
plt.title("Signal S[n]") 
plt.figure()

for i in range(len(n)):                          # getting y till the range of n
    y[i] = 0.5*( y[i-1] + x[i]/y[i-1] )          # defining the y as per the equation given in question
plt.plot(n,y)                                    # plot y to verify
plt.xlabel("n")
plt.ylabel("Y[n]")
plt.title("Signal Y[n]")
# Out:
# 1.0
# 0.9
# 0.81
# 0.7290000000000001
# 0.6561
# 0.5904900000000001
# 0.531441
# 0.4782969000000001
# 0.4304672100000001
# 0.3874204890000001
# 0.3486784401000001
# 0.31381059609000006
# 0.2824295364810001
# 0.2541865828329001
# 0.2287679245496101
# 0.20589113209464907
# 0.18530201888518416
# 0.16677181699666577
# 0.15009463529699918
# 0.13508517176729928
# 0.12157665459056935
# 0.10941898913151242
# 0.09847709021836118
# 0.08862938119652507
# 0.07976644307687256
# 0.0717897987691853
# 0.06461081889226677
# 0.058149737003040096
# 0.05233476330273609
# 0.047101286972462485
# 0.04239115827521624
# 0.038152042447694615
# 0.03433683820292515
# 0.030903154382632636
# 0.027812838944369374
# 0.025031555049932437
# 0.022528399544939195
# 0.020275559590445275
# 0.01824800363140075
# 0.016423203268260675
# 0.014780882941434608
# 0.013302794647291146
# 0.011972515182562033
# 0.01077526366430583
# 0.009697737297875247
# 0.008727963568087723
# 0.00785516721127895
# 0.007069650490151055
# 0.00636268544113595
# 0.005726416897022355
# 0.00515377520732012
# 0.004638397686588108
# 0.004174557917929297
# 0.0037571021261363674
# 0.0033813919135227306
# 0.0030432527221704577
# 0.002738927449953412
# 0.002465034704958071
# 0.002218531234462264
# 0.0019966781110160375
# 0.001797010299914434
# 0.0016173092699229906
# 0.0014555783429306916
# 0.0013100205086376223
# 0.0011790184577738603
# 0.001061116611996474
# 0.0009550049507968268
# 0.0008595044557171441
# 0.0007735540101454297
# 0.0006961986091308868
# 0.0006265787482177981
# 0.0005639208733960184
# 0.0005075287860564165
# 0.00045677590745077487
# 0.0004110983167056974
# 0.00036998848503512764
# 0.0003329896365316149
# 0.0002996906728784534
# 0.0002697216055906081
# 0.0002427494450315473
# 0.00021847450052839255
# 0.00019662705047555332
# 0.00017696434542799797
# 0.00015926791088519818
# 0.00014334111979667836
# 0.00012900700781701054
# 0.00011610630703530949
# 0.00010449567633177854
# 9.404610869860069e-05
# 8.464149782874062e-05
# 7.617734804586657e-05
# 6.85596132412799e-05
# 6.170365191715192e-05
# 5.553328672543673e-05
# 4.997995805289306e-05
# 4.498196224760375e-05
# 4.0483766022843375e-05
# 3.643538942055904e-05
# 3.279185047850314e-05
# 2.9512665430652825e-05
# 2.6561398887587544e-05
# Text(0.5, 1.0, 'Signal Y[n]')
